# %% [markdown]
# Plotting

# %%
#!pip install altair
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/winterForestStump/RNWF/main/data/rnwf.csv')

# %%
df[['Date', 'amount_blnUSD', 'amount_blnRUB']].head()
# Out:
#          Date  amount_blnUSD  amount_blnRUB
# 0  2024-10-01         137.92       12787.13
# 1  2024-09-01         133.42       12165.77
# 2  2024-08-01         142.22       12277.51
# 3  2024-07-01         146.96       12601.67
# 4  2024-06-01         141.49       12703.81

# %%
print(f"By {df['Date'][0]} the amount of the RNWF was USD {df['amount_blnUSD'][0]} bln or RUB {df['amount_blnRUB'][0]} bln")
# Out:
# By 2024-10-01 the amount of the RNWF was USD 137.92 bln or RUB 12787.13 bln

# %% [markdown]
# RNWF in USD

# %%
datetime_invasion = pd.to_datetime('24.02.2022', format='%d.%m.%Y')
line = alt.Chart(df).mark_line(point=True).encode(
    x=alt.X("Date(m,Y):T", axis=alt.Axis(title=None, format=("%b %Y"), labelAngle=45)), 
    y=alt.Y('amount_blnUSD:Q'), 
    tooltip = ["Date(m,Y):T", 'amount_blnUSD:Q'])
rule = alt.Chart(pd.DataFrame({'datetime_invasion': [datetime_invasion]})).mark_rule(color='red').encode(x='datetime_invasion:T')
(line + rule).properties(title='Fund amount in USD', width=1000)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# RNWF in RUB

# %%
line = alt.Chart(df).mark_line(point=True).encode(
    x=alt.X("Date(m,Y):T", axis=alt.Axis(title=None, format=("%b %Y"), labelAngle=90)), 
    y=alt.Y('amount_blnRUB:Q'),
    tooltip = ["Date(m,Y):T", 'amount_blnRUB:Q'])
rule = alt.Chart(pd.DataFrame({'datetime_invasion': [datetime_invasion]})).mark_rule(color='red').encode(x='datetime_invasion:T')
(line + rule).properties(title='Fund amount in RUB', width=1000)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Structure of the RNWF

# %%
df_structure = pd.read_csv('https://raw.githubusercontent.com/winterForestStump/RNWF/main/data/rnwf_structure.csv', header=None, sep=';')

# %%
df_structure = df_structure.T
df_structure.columns = df_structure.iloc[0]
df_structure = df_structure[1:] # drop the first row, as it is now the header
df_structure['Data'] = pd.to_datetime(df_structure['Data'], format='%d.%m.%Y', errors='coerce') #for not silent fail

# %%
# remove the percentage sign and replace commas with dots, then convert to float
df_structure['Share of liquid assets in the total Fund in USD equivalent'] = df_structure['Share of liquid assets in the total Fund in USD equivalent'].str.replace(',', '.').str.rstrip('%').astype('float')

# %%
df_structure
# Out:
# 0        Data Volume of the National Wealth Fund, RUB mln
# 1  2022-10-01                                  10792185.6  \
# 2  2022-11-01                                  11374082.0
# 3  2022-12-01                                  11389507.9
# 4  2023-01-01                                  10434580.8
# 5  2023-02-01                                  10807595.0
# 6  2023-03-01                                  11106403.6
# 7  2023-04-01                                  11906061.4
# 8  2023-05-01                                  12475588.3
# 9  2023-06-01                                  12353145.8
# 10 2023-07-01                                  12670270.1
# 11 2023-08-01                                  13313450.5
# 12 2023-09-01                                  13703597.7
# 13 2023-10-01                                  13648337.7
# 14 2023-11-01                                  13541231.5
# 15 2023-12-01                                  13432971.8
# 16 2024-01-01                                  11965074.7
# 17 2024-02-01                                  11922371.2
# 18 2024-03-01                                  12258661.2
# 19 2024-04-01                                  12534406.3
# 20 2024-05-01                                  12750839.4
# 21 2024-06-01                                  12703814.5
# 22 2024-07-01                                  12601672.4
# 23 2024-08-01                                  12277510.9
# 24 2024-09-01                                  12165767.0
#
# 0  Volume of the National Wealth Fund, USD mln
# 1                                     187974.6  \
# 2                                     184841.3
# 3                                     186486.4
# 4                                     148350.2
# 5                                     155297.8
# 6                                     147236.7
# 7                                     154451.1
# 8                                     154958.3
# 9                                     153099.2
# 10                                    145578.2
# 11                                    146336.5
# 12                                    142852.5
# 13                                    140105.5
# 14                                    145224.4
# 15                                    151129.1
# 16                                    133407.3
# 17                                    133526.1
# 18                                    133436.0
# 19                                    135703.7
# 20                                    138929.7
# 21                                    141488.5
# 22                                    146961.7
# 23                                    142216.0
# 24                                    133415.9
#
# 0  Balance on Federal Treasury accounts with the Bank of the Russia, EUR mln
# 1                                             49188.8                         \
# 2                                             45733.5
# 3                                             41891.7
# 4                                             10464.5
# 5                                             10464.5
# 6                                             10464.5
# 7                                             10398.8
# 8                                              9233.6
# 9                                              9054.6
# 10                                             7278.7
# 11                                             7278.7
# 12                                             5224.6
# 13                                             4070.6
# 14                                             3666.6
# 15                                             3268.8
# 16                                                0.0
# 17                                                0.0
# 18                                                0.0
# 19                                                0.0
# 20                                                0.0
# 21                                                0.0
# 22                                                0.0
# 23                                                0.0
# 24                                                0.0
#
# 0  Balance on Federal Treasury accounts with the Bank of the Russia, CNY mln
# 1                                            309720.1                         \
# 2                                            309720.1
# 3                                            309720.1
# 4                                            309720.1
# 5                                            307445.9
# 6                                            300067.9
# 7                                            292588.8
# 8                                            288330.1
# 9                                            285736.1
# 10                                           282284.2
# 11                                           280158.9
# 12                                           279773.7
# 13                                           279773.7
# 14                                           279773.7
# 15                                           279773.7
# 16                                           227330.7
# 17                                           227517.1
# 18                                           227517.1
# 19                                           227615.8
# 20                                           227615.8
# 21                                           227615.8
# 22                                           229532.6
# 23                                           226532.6
# 24                                           223782.6
#
# 0  Balance on Federal Treasury accounts with the Bank of the Russia, GOLD kg
# 1                                            554910.5                         \
# 2                                            554910.5
# 3                                            554910.5
# 4                                            554910.5
# 5                                            551277.5
# 6                                            539245.1
# 7                                            527382.3
# 8                                            520974.0
# 9                                            517114.1
# 10                                           511986.9
# 11                                           508835.4
# 12                                           508265.3
# 13                                           508265.3
# 14                                           508265.3
# 15                                           508265.3
# 16                                           358960.6
# 17                                           358960.6
# 18                                           358014.6
# 19                                           334863.2
# 20                                           334367.3
# 21                                           329705.3
# 22                                           303578.6
# 23                                           298840.4
# 24                                           293188.6
#
# 0  Balance on Federal Treasury accounts with the Bank of the Russia, RUB mln
# 1                                               264.3                         \
# 2                                               526.7
# 3                                               242.7
# 4                                               274.8
# 5                                               530.1
# 6                                              6124.0
# 7                                               140.7
# 8                                               232.8
# 9                                               228.0
# 10                                              400.4
# 11                                             5490.5
# 12                                             6775.9
# 13                                              395.9
# 14                                              261.8
# 15                                             1187.6
# 16                                             1514.0
# 17                                              294.8
# 18                                             1241.0
# 19                                             1650.1
# 20                                              299.7
# 21                                             1252.0
# 22                                             1676.0
# 23                                              368.5
# 24                                             1261.9
#
# 0  Deposits and subordinated debt with VEB_RF, RUB mln
# 1                                            528449.0   \
# 2                                            528186.0
# 3                                            650116.0
# 4                                            649841.0
# 5                                            649586.0
# 6                                            649346.0
# 7                                            648927.0
# 8                                            648694.0
# 9                                            648466.0
# 10                                           653020.0
# 11                                           655170.8
# 12                                           656580.0
# 13                                           657029.3
# 14                                           657764.8
# 15                                           658364.9
# 16                                           658828.3
# 17                                           658595.7
# 18                                           658293.5
# 19                                  657832.8999999999
# 20                                           659635.9
# 21                                           660216.1
# 22                                           660688.7
# 23                                           689427.9
# 24                                           690022.5
#
# 0  Debt obligations of foreign countries, USD mln
# 1                                          3000.0  \
# 2                                          3000.0
# 3                                          3000.0
# 4                                          3000.0
# 5                                          3000.0
# 6                                          3000.0
# 7                                          3000.0
# 8                                          3000.0
# 9                                          3000.0
# 10                                         3000.0
# 11                                         3000.0
# 12                                         3000.0
# 13                                         3000.0
# 14                                         3000.0
# 15                                         3000.0
# 16                                         3000.0
# 17                                         3000.0
# 18                                         3000.0
# 19                                         3000.0
# 20                                         3000.0
# 21                                         3000.0
# 22                                         3000.0
# 23                                         3000.0
# 24                                         3000.0
#
# 0  Securities of Russian issuers related to the implementation of self-sustaining infrastructure projects, RUB mln
# 1                                            314357.4                                                               \
# 2                                            319388.7
# 3                                            385146.2
# 4                                            583710.0
# 5                                            583710.0
# 6                                            583710.0
# 7                                            595596.0
# 8                                            603639.1
# 9                                            619314.4
# 10                                           697875.5
# 11                                           703010.4
# 12                                           862315.2
# 13                                           918404.2
# 14                                           940395.4
# 15                                           973116.7
# 16                                          1157407.0
# 17                                          1157407.0
# 18                                          1163373.0
# 19                                          1179302.0
# 20                                          1182890.0
# 21                                          1213962.3
# 22                                          1231367.6
# 23                                          1236574.6
# 24                                          1262976.0
#
# 0  Securities of Russian issuers related to the implementation of self-sustaining infrastructure projects, USD mln
# 1                                              2221.4                                                               \
# 2                                              2221.4
# 3                                              2221.4
# 4                                              2153.4
# 5                                              2153.4
# 6                                              2082.4
# 7                                              2082.4
# 8                                              2082.4
# 9                                              2082.4
# 10                                             2014.4
# 11                                             2014.4
# 12                                             1943.5
# 13                                             1943.5
# 14                                             1943.5
# 15                                             1943.5
# 16                                             1875.5
# 17                                             1875.5
# 18                                             1875.5
# 19                                             1875.5
# 20                                             1875.5
# 21                                             1875.4
# 22                                             1875.4
# 23                                             1875.4
# 24                                             1875.4
#
# 0  Preferred shares of credit organizations, RUB mln
# 1                                           328991.9  \
# 2                                           328991.9
# 3                                           328991.9
# 4                                           328991.9
# 5                                           328991.9
# 6                                           328991.9
# 7                                           328991.9
# 8                                           328991.9
# 9                                           328991.9
# 10                                          328991.9
# 11                                          328991.9
# 12                                          328991.9
# 13                                          328991.9
# 14                                          328991.9
# 15                                          328991.9
# 16                                          328991.9
# 17                                          328991.9
# 18                                          328991.9
# 19                                          328991.9
# 20                                          328991.9
# 21                                          328991.9
# 22                                          403991.9
# 23                                          403991.9
# 24                                          403991.9
#
# 0  Subordinated debt with GAZPROMBANK, RUB mln Common stocks, RUB mln
# 1                                          0.0              1393665.3  \
# 2                                          0.0              1601086.9
# 3                                          0.0              1702023.3
# 4                                          0.0              1757319.5
# 5                                          0.0              1932491.9
# 6                                          0.0              2095160.2
# 7                                      38433.9              2709111.9
# 8                                      38433.9              3041875.2
# 9                                      38433.9              3088748.3
# 10                                     38433.9              3128294.4
# 11                                     38433.9     3384520.6999999997
# 12                                     38433.9              3465106.2
# 13                                     38433.9              3389191.3
# 14                                     38433.9     3463670.0000000005
# 15                                     38433.9              3530974.0
# 16                                     38433.9     3479595.8999999994
# 17                                     38433.9     3544601.3999999994
# 18                                     38433.9              3726117.6
# 19                                     38433.9              3807455.2
# 20                                     38433.9              3937682.4
# 21                                     38433.9              3995946.6
# 22                                     38433.9              4167665.7
# 23                                     38433.9     3710250.0999999996
# 24                                     38433.9              3313410.9
#
# 0  Preferred shares, RUB mln Bonds, RUB mln Bonds, CNY mln
# 1                   250000.0        14150.8            0.0  \
# 2                   250000.0        14150.8            0.0
# 3                   250000.0        14150.8            0.0
# 4                   467000.0        14150.8            0.0
# 5                   467000.0        14150.8            0.0
# 6                   467000.0        14150.8            0.0
# 7                   467000.0        14150.8            0.0
# 8                   467000.0       109098.9            0.0
# 9                   467000.0       109098.9            0.0
# 10                  467000.0       109098.9            0.0
# 11                  467000.0        96722.8            0.0
# 12                  467000.0       159313.4            0.0
# 13                  467000.0       227543.5            0.0
# 14                  467000.0       245719.7            0.0
# 15                  467000.0       250195.1            0.0
# 16                  467000.0       385771.2            0.0
# 17                  467000.0       384966.4            0.0
# 18                  467000.0       383946.4            0.0
# 19                  467000.0       517310.5            0.0
# 20                  467000.0       516505.8            0.0
# 21                  467000.0       515485.7            0.0
# 22                  467000.0       611147.5            0.0
# 23                  467000.0       610342.8         3000.0
# 24                  467000.0       621822.7         5750.0
#
# 0  Volume of liquid assets of the Fund, RUB mln
# 1                                     7524361.3  \
# 2                                     7872548.3
# 3                                     7601763.0
# 4                                     6132655.2
# 5                                     6334590.6
# 6                                     6446231.0
# 7                                     6712063.4
# 8                                     6828671.4
# 9                                     6643004.4
# 10                                    6811125.0
# 11                                    7183391.5
# 12                                    7251634.9
# 13                                    7140176.1
# 14                                    6938308.8
# 15                                    6746505.1
# 16                                    5011778.0
# 17                                    4907126.4
# 18                                    5044614.2
# 19                                    5087766.7
# 20                                    5172247.3
# 21                                    5046039.0
# 22                                    4603329.1
# 23                                    4665093.0
# 24                                    4854458.2
#
# 0  Volume of liquid assets of the Fund, USD mln
# 1                                      131056.8  \
# 2                                      127937.6
# 3                                      124467.7
# 4                                       87189.0
# 5                                       91023.8
# 6                                       85457.2
# 7                                       87072.1
# 8                                       84818.4
# 9                                       82330.3
# 10                                      78258.1
# 11                                      78957.2
# 12                                      75594.3
# 13                                      73296.7
# 14                                      74410.6
# 15                                      75905.3
# 16                                      55880.0
# 17                                      54958.0
# 18                                      54910.8
# 19                                      55082.7
# 20                                      56355.4
# 21                                      56200.2
# 22                                      53684.4
# 23                                      54037.9
# 24                                      53236.4
#
# 0   Share of liquid assets in the total Fund in USD equivalent
# 1                                            0.697205
# 2                                            0.692148
# 3                                            0.667436
# 4                                            0.587724
# 5                                            0.586124
# 6                                            0.580407
# 7                                            0.563752
# 8                                            0.547363
# 9                                            0.537758
# 10                                           0.537567
# 11                                           0.539559
# 12                                           0.529177
# 13                                           0.523154
# 14                                           0.512384
# 15                                           0.502255
# 16                                           0.418868
# 17                                           0.411590
# 18                                           0.411514
# 19                                           0.405904
# 20                                           0.405640
# 21                                           0.397207
# 22                                           0.365295
# 23                                           0.379971
# 24                                           0.399026

# %% [markdown]
# Function for plotting a line with amount dynamics:

# %%
def plot_line(text):
    line = alt.Chart(df_structure).mark_line(point=True).encode(
    x=alt.X("Data:T", axis=alt.Axis(title=None, format=("%b %Y"), labelAngle=45)), 
    y=alt.Y(f'{text}:Q'),
    tooltip=["Data:T", f'{text}:Q'])

    return alt.layer(line).properties(title=f'{text}', width=1000)

# %% [markdown]
# Volume of liquid assets of the Fund, USD mln

# %%
line = alt.Chart(df_structure).mark_line(point=True).encode(
    x=alt.X("Data:T", axis=alt.Axis(title=None, format=("%b %Y"), labelAngle=45)), 
    y=alt.Y("Volume of liquid assets of the Fund, USD mln:Q"),
    tooltip=["Data:T", 'Volume of liquid assets of the Fund, USD mln:Q'])

percent = alt.Chart(df_structure).mark_line(color='red').encode(
    x=alt.X("Data:T", axis=alt.Axis(title=None, format=("%b %Y"), labelAngle=45)), 
    y=alt.Y('Share of liquid assets in the total Fund in USD equivalent:Q', axis=alt.Axis(title='Share of liquid assets in the total Fund in USD equivalent'), scale=alt.Scale(domain=[0, 1])),
    tooltip=["Data:T", 'Share of liquid assets in the total Fund in USD equivalent:Q'])

combined_chart = alt.layer(line, percent).resolve_scale(y='independent').properties(title='Volume of liquid assets of the Fund, USD mln', width=1000)

combined_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Balance on Federal Treasury accounts with the Bank of the Russia, EUR mln

# %%
plot_line("Balance on Federal Treasury accounts with the Bank of the Russia, EUR mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Balance on Federal Treasury accounts with the Bank of the Russia, CNY mln

# %%
plot_line('Balance on Federal Treasury accounts with the Bank of the Russia, CNY mln')
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Balance on Federal Treasury accounts with the Bank of the Russia, GOLD kg

# %%
plot_line('Balance on Federal Treasury accounts with the Bank of the Russia, GOLD kg')
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Balance on Federal Treasury accounts with the Bank of the Russia, RUB mln:

# %%
plot_line("Balance on Federal Treasury accounts with the Bank of the Russia, RUB mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Deposits and subordinated debt with VEB.RF, RUB mln:

# %%
plot_line("Deposits and subordinated debt with VEB_RF, RUB mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Debt obligations of foreign countries, USD mln:

# %%
plot_line("Debt obligations of foreign countries, USD mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Securities of Russian issuers related to the implementation of self-sustaining infrastructure projects, RUB mln

# %%
plot_line('Securities of Russian issuers related to the implementation of self-sustaining infrastructure projects, RUB mln')
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Securities of Russian issuers related to the implementation of self-sustaining infrastructure projects, USD mln

# %%
plot_line("Securities of Russian issuers related to the implementation of self-sustaining infrastructure projects, USD mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Preferred shares of credit organizations, RUB mln:

# %%
plot_line("Preferred shares of credit organizations, RUB mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Subordinated debt with GAZPROMBANK, RUB mln:

# %%
plot_line("Subordinated debt with GAZPROMBANK, RUB mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Common stocks, RUB mln:

# %%
plot_line("Common stocks, RUB mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Preferred shares, RUB mln:

# %%
plot_line("Preferred shares, RUB mln")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Bonds, RUB mln:

# %%
plot_line("Bonds, RUB mln")
# Out:
# alt.LayerChart(...)
