# %%
! CMAKE_ARGS="-DGGML_BLAS=ON -DGGML_BLAS_VENDOR=OpenBLAS" pip install llama-cpp-python --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 MB 10.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli download winterForestStump/Llama-3.2-3B-Instruct-CBR_Bonds_info unsloth.Q4_K_M.gguf --local-dir ./models --local-dir-use-symlinks False
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/commands/download.py:139: FutureWarning: Ignoring --local-dir-use-symlinks. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...
# unsloth.Q4_K_M.gguf: 100% 2.02G/2.02G [00:47<00:00, 42.3MB/s]
# Download complete. Moving file to models/unsloth.Q4_K_M.gguf
# models/unsloth.Q4_K_M.gguf

# %%
from llama_cpp import Llama

# %%
llm = Llama(
      model_path="/content/models/unsloth.Q4_K_M.gguf",
      # n_gpu_layers=-1, # Uncomment to use GPU acceleration
      seed=1337, # Uncomment to set a specific seed
      n_ctx=2048, # Uncomment to increase the context window
)
# Out:
# llama_model_loader: loaded meta data with 30 key-value pairs and 255 tensors from /content/models/unsloth.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Llama 3.2 3b Instruct Bnb 4bit
# llama_model_loader: - kv   3:                       general.organization str              = Unsloth
# llama_model_loader: - kv   4:                           general.finetune str              = instruct-bnb-4bit
# llama_model_loader: - kv   5:                           general.basename str              = llama-3.2
# llama_model_loader: - kv   6:                         general.size_label str              = 3B
# ...

# %%
def generate_prompt(text) -> str:
    prompt = f"""
    # Instruction: You have to extract securities registration numbers from the provided text.
    # Provided text: {text}.
    # Securities registration numbers:
    """
    return prompt

# %%
def execute(text):
    prompt = generate_prompt(text)
    output = llm(
      prompt,
      max_tokens=512,
      stop = ['<|eot_id|>'],
      echo=False)
    return output

# %%
test = """
Банк России 25.03.2024 принял решение о государственной регистрации отчета об итогах дополнительного выпуска обыкновенных акций акционерного общества
«Корпорация развития жилищного строительства» (Приморский край), размещенных путем закрытой подписки, регистрационный номер дополнительного выпуска
1-01-50157-A-013D.
"""

# %%
execute(test)
# Out:
# Llama.generate: 28 prefix-match hit, remaining 99 prompt tokens to eval
# llama_perf_context_print:        load time =   26198.76 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    99 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   511 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  224222.29 ms /   610 tokens
# {'id': 'cmpl-da344589-b391-48d6-9c80-0e2534ec89db',
#  'object': 'text_completion',
#  'created': 1733065775,
#  'model': '/content/models/unsloth.Q4_K_M.gguf',
# ...

# %%
test_2 = """
Банк России 18.03.2024 принял решение о государственной регистрации изменений в решение о выпуске неконвертируемых процентных бездокументарных облигаций
серии П001-02, размещаемых в рамках программы облигаций серии П001, общества с ограниченной ответственностью «Проспект» (г. Москва),
регистрационный номер выпуска 4-02-00697-R-001P.
"""

# %%
execute(test_2)
# Out:
# Llama.generate: 28 prefix-match hit, remaining 118 prompt tokens to eval
# llama_perf_context_print:        load time =   26198.76 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /   118 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   511 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  226655.45 ms /   629 tokens
# {'id': 'cmpl-95020322-e6f6-4283-8c7a-aa364c1765b5',
#  'object': 'text_completion',
#  'created': 1733066000,
#  'model': '/content/models/unsloth.Q4_K_M.gguf',
# ...

# %%
test_3 = """
Банк России 18.03.2024 принял решение о государственной регистрации выпусков неконвертируемых процентных бездокументарных облигаций
серий З026-1-ФР и З026-2-Р, размещаемых в рамках программы облигаций серии 003Р, открытого акционерного общества «Российские железные дороги» (г. Москва).
Выпускам ценных бумаг присвоены регистрационные номера 4-01-65045-D-002P и 4-02-65045-D-002P соответственно.
"""

# %%
execute(test_3)
# Out:
# Llama.generate: 44 prefix-match hit, remaining 134 prompt tokens to eval
# llama_perf_context_print:        load time =   26198.76 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /   134 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   511 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  222752.46 ms /   645 tokens
# {'id': 'cmpl-12cc0ebe-d181-4e2d-846a-1208d7cc2351',
#  'object': 'text_completion',
#  'created': 1733066226,
#  'model': '/content/models/unsloth.Q4_K_M.gguf',
# ...

# %%
test_4 = """
Банк России 14.03.2024 принял решение о государственной регистрации выпусков структурных процентных дисконтных неконвертируемых бездокументарных облигаций
с централизованным учетом прав серий С-1-991, С-1-992, С-1-993, С-1-994, С-1-995, С-1-996, С-1-997, С-1-998, С-1-999, С-1-1000, С-1-1001, С-1-1002, С-1-1003,
С-1-1004, С-1-1005, С-1-1006, С-1-1007, С-1-1008, С-1-1009, С-1-1010, размещаемых в рамках программы облигаций Банка ВТБ (публичное акционерное общество)
(г. Санкт-Петербург). Выпускам ценных бумаг присвоены регистрационные номера
6-991-01000-В-001P, 6-992-01000-В-001P, 6-993-01000-В-001P, 6-994-01000-В-001P, 6-995-01000-В-001P, 6-996-01000-В-001P, 6-997-01000-В-001P, 6-998-01000-В-001P,
6-999-01000-В-001P, 6-1000-01000-В-001P, 6-1001-01000-В-001P, 6-1002-01000-В-001P, 6-1003-01000-В-001P, 6-1004-01000-В-001P, 6-1005-01000-В-001P, 6-1006-01000-В-001P,
6-1007-01000-В-001P, 6-1008-01000-В-001P, 6-1009-01000-В-001P, 6-1010-01000-В-001P соответственно.
"""

# %%
execute(test_4)
# Out:
# Llama.generate: 28 prefix-match hit, remaining 508 prompt tokens to eval
# llama_perf_context_print:        load time =   26198.76 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /   508 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   511 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  276877.62 ms /  1019 tokens
# {'id': 'cmpl-b27a647f-d399-4353-abff-f1d7afab676a',
#  'object': 'text_completion',
#  'created': 1733066449,
#  'model': '/content/models/unsloth.Q4_K_M.gguf',
# ...
